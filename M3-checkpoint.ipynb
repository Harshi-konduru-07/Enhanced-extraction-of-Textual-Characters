# %% [markdown]
# # Image To Text and Audio Conversion

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
import easyocr
import pyttsx3

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
reader=easyocr.Reader(['en'], gpu=False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
result=reader.readtext('img.jpg')

# %%
result
# Out:
# [([[70, 212], [854, 212], [854, 291], [70, 291]],
#   'The best feeling in the world',
#   0.915563155101486),
#  ([[71, 319], [853, 319], [853, 387], [71, 387]],
#   'is to know that you are mine',
#   0.758330887145258),
#  ([[249, 417], [675, 417], [675, 484], [249, 484]],
#   'and | am yours:',
#   0.6197135848541516),
#  ([[54, 503], [870, 503], [870, 590], [54, 590]],
#   'Every morning that is enough',
#   0.9424824028462123),
#  ([[94, 609], [706, 609], [706, 684], [94, 684]],
#   'for me to have a good',
#   0.8079693549395945),
#  ([[294, 838], [628, 838], [628, 868], [294, 868]],
#   'E V E R Y DA Y Pow E R',
#   0.4420625267171665),
#  ([[710.9193618380847, 607.0839157637423],
#    [834.7327293220329, 627.0841827132426],
#    [823.0806381619153, 684.9160842362577],
#    [698.2672706779671, 665.9158172867574]],
#   'day:',
#   0.8602044407241308)]

# %%
text=''

for i in range(len(result)):
    text=text+' '+result[i][1]
    
print(text)
# Out:
#  The best feeling in the world is to know that you are mine and | am yours: Every morning that is enough for me to have a good E V E R Y DA Y Pow E R day:

# %%
print(result[0][1])
# Out:
# The best feeling in the world

# %%
top_left=tuple(result[0][0][0])
bottom_right=tuple(result[0][0][2])
text=result[0][1]
font=cv2.FONT_HERSHEY_SIMPLEX

# %%
top_left
# Out:
# (70, 212)

# %%
bottom_right
# Out:
# (854, 291)

# %%
text
# Out:
# 'The best feeling in the world'

# %%
img=cv2.imread('img.jpg')
img=cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
img=cv2.putText(img, text, top_left,font, 1, (0,0,255),2, cv2.LINE_AA)
plt.imshow(img)
plt.show()

# %%
# Handling Multiple lines

img=cv2.imread('img.jpg')
for detection in result:
    top_left=tuple([int(val) for val in detection[0][0]])
    bottom_right=tuple([int(val) for val in detection[0][2]])
    text=detection[1]
    print(text)
    font=cv2.FONT_HERSHEY_SIMPLEX
    img=cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
    img=cv2.putText(img, text, top_left,font, 1, (0,0,255),2, cv2.LINE_AA)
    
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
# Out:
# The best feeling in the world
# is to know that you are mine
# and | am yours:
# Every morning that is enough
# for me to have a good
# E V E R Y DA Y Pow E R
# day:

# %%
# Reading the text and converting into scentense

# Handling Multiple lines
import cv2
img=cv2.imread('img.jpg')
text=''
for detection in result:
    top_left=tuple([int(val) for val in detection[0][0]])
    bottom_right=tuple([int(val) for val in detection[0][2]])
    text=text+' '+detection[1]
print(text)


# Calculating number of words
len(text.split())
# Out:
#  The best feeling in the world is to know that you are mine and | am yours: Every morning that is enough for me to have a good E V E R Y DA Y Pow E R day:
# 39

# %%
import pyttsx3
engine = pyttsx3.init()
engine.setProperty('rate', 130)
engine.say(text)
engine.runAndWait()
